# %% [markdown]
# # Design and implement a simple command-line calculator application in Python, utilizing functions to perform basic arithmetic operations. The primary objective is to create an interactive and user-friendly calculator that allows users to perform:
# 1.addition
# 2.subtraction
# 3.Multiplication
# 4.division  on two input numbers.
# The project aims to demonstrate proficiency in function-based programming, user input validation, and code organization. The end result should be a functional and well-structured calculator application that provides a seamless user experience while adhering to best practices in Python programming.

# %%
print("Welcome!\n")

def mul(x,y):
    answer = x*y
    return answer

def addition(x,y):
    answer = x+y
    return answer

def subtraction(x,y):
    answer = x-y
    return answer

def division(x,y):
    try:
        answer = x/y
        return answer
    except:
        print('An exception occured')
        


while True:
    
    function= int(input("Enter the number of the function you need to perform. \n1. Addition\n2. Subtraction\n3. Multiplication\n4. Division\n5. Stop computing\n"))
    if function == 5:
                        print("Thank you!")
                        break
    elif function == 1:
        num1= eval(input("Enter the first number : "))
        num2= eval(input("Enter the second number : "))
        answer = addition(num1,num2)
        print("\nThe result is : ",answer)
        
    elif function == 2:
        num1= eval(input("Enter the first number : "))
        num2= eval(input("Enter the second number : "))
        answer = subtraction(num1,num2)        
        print("\nThe result is : ",answer)
        
    
    elif function == 3:
        num1= eval(input("Enter the first number : "))
        num2= eval(input("Enter the second number : "))
        answer = mul(num1,num2)
        print("\nThe result is : ",answer)
    
    elif function == 4:
        num1= eval(input("Enter the first number : "))
        num2= eval(input("Enter the second number : "))
        answer = division(num1,num2)
        print("\nThe result is : ",answer)
# Out:
# Welcome!
#
# Enter the number of the function you need to perform.
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Stop computing
# 1
# Enter the first number : 56
# Enter the second number : 958
#
# The result is :  1014
# Enter the number of the function you need to perform.
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Stop computing
# 2
# Enter the first number : 525
# Enter the second number : 448
#
# The result is :  77
# Enter the number of the function you need to perform.
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Stop computing
# 3
# Enter the first number : 56
# Enter the second number : 0
#
# The result is :  0
# Enter the number of the function you need to perform.
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Stop computing
# 698
# Enter the number of the function you need to perform.
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Stop computing
# 474
# Enter the number of the function you need to perform.
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Stop computing
# 4
# Enter the first number : 565
# Enter the second number : 478
#
# The result is :  1.1820083682008369
# Enter the number of the function you need to perform.
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Stop computing
# 5
# Thank you!

# %%
print("Welcome!\n")

def mul(x,y):
    answer = x*y
    return answer

def addition(x,y):
    answer = x+y
    return answer

def subtraction(x,y):
    answer = x-y
    return answer

def division(x,y):
    try:
        answer = x/y
        return answer
    except:
        print('An exception occured')
        


while True:
    
    num1= eval(input("Enter the first number [type 'done' to stop]: "))
    num2= eval(input("Enter the second number [type 'done' to stop]: "))

    if num1 == 'done' or num2 == 'done':
        print('Thank you')
        break
        
    function= int(input("Enter the number of the function you need to perform. \n1. Addition\n2. Subtraction\n3. Multiplication\n4. Division\n"))

        
    elif function == 1:
                        answer = addition(num1,num2)
                        print("\nThe result is : ",answer)
    elif function == 2:
                        answer = subtraction(num1,num2)
                        print("\nThe result is : ",answer)
    elif function == 3:
                        answer = mul(num1,num2)
                        print("\nThe result is : ",answer)
    elif function == 4:
                        answer = division(num1,num2)
                        print("\nThe result is : ",answer)
# Out:
#   Cell In[27], line 36
#     elif function == 1:
#     ^
# SyntaxError: invalid syntax
